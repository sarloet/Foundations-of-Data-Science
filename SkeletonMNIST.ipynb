# %% [markdown]
# <a href="https://colab.research.google.com/github/sarloet/Foundations-of-Data-Science/blob/main/SkeletonMNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical 3: MNIST
#
# This is the first task of Practical 3. Your task is to build a (convolutional) neural network to classify the handwritten digits from the MNIST dataset (http://yann.lecun.com/exdb/mnist/).
#
# You should get an accuracy of **at least 97%** to pass the practical.
#
# The model files might be too large to be uploaded to GitHub.
# Please use the following link to upload your models: https://seafile.ifi.uzh.ch/u/d/695f63e725b641ed8633/
#
# Name the model file `{repository_name}-MNIST.h5`. For example, if your repository is FDS22-M0, you should name the model file `FDS22-M0-MNIST.h5`. If you are not satisfied with the model you have uploaded, you can upload a new one with the same name. We will only look at the newest model. Nevertheless, try to upload as few times as possible, since the online drive has a limited amount of space.

# %% [markdown]
# ## Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
tf.keras.__version__
# Out:
# '2.9.0'

# %% [markdown]
# ## Prepare the dataset
#
# In this block, you will prepare the data for the training, such as normalisation.

# %%
from keras.datasets import mnist
(X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()

for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.imshow(X_train_full[i])
plt.show()

print(X_train_full.shape)

# reshape dataset to have a single channel
X_train_full = X_train_full.reshape((X_train_full.shape[0], 28, 28, 1))
X_test = X_test.reshape((X_test.shape[0], 28, 28, 1))

# Converts a class vector (integers) to one-hot encoding matrix.
y_train_full = keras.utils.to_categorical(y_train_full)
y_test = keras.utils.to_categorical(y_test)

# normalisation
X_train_full = X_train_full/255.0
X_test = X_test/255.0

# get validation dataset
np.random.seed(42) # we set the random seed to make sure everytime the data is shuffled in the same way 
shuffled_indices = np.random.permutation(X_train_full.shape[0])
X_valid, X_train = X_train_full[shuffled_indices[:5000]], X_train_full[shuffled_indices[5000:]]
y_valid, y_train = y_train_full[shuffled_indices[:5000]], y_train_full[shuffled_indices[5000:]]



print(X_train_full.shape)
print(type(X_train_full))
# Out:
# (60000, 28, 28)
# (60000, 28, 28, 1)
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Build and train the model
#
# Build and train your model.

# %%
# TODO: Build your model
model = keras.models.Sequential([
    keras.layers.Conv2D(filters=64, kernel_size=7, activation="relu", kernel_initializer='he_uniform', padding="same", input_shape=[28, 28, 1]),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", kernel_initializer='he_uniform', padding="same"), 
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Flatten(), # starting fully connected layers
    keras.layers.Dense(128, activation="relu", kernel_initializer='he_uniform'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation="softmax")
])
model.summary()

model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(),
              metrics=["accuracy"])

history = model.fit(X_train, y_train, batch_size=32, epochs=30, 
                    validation_data=(X_valid, y_valid))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        3200
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 881,290
# Trainable params: 881,290
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1719/1719 [==============================] - 17s 5ms/step - loss: 0.2366 - accuracy: 0.9295 - val_loss: 0.0520 - val_accuracy: 0.9862
# Epoch 2/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0833 - accuracy: 0.9755 - val_loss: 0.0446 - val_accuracy: 0.9860
# Epoch 3/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0592 - accuracy: 0.9824 - val_loss: 0.0418 - val_accuracy: 0.9884
# Epoch 4/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0469 - accuracy: 0.9864 - val_loss: 0.0321 - val_accuracy: 0.9898
# Epoch 5/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0392 - accuracy: 0.9885 - val_loss: 0.0371 - val_accuracy: 0.9886
# Epoch 6/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0308 - accuracy: 0.9910 - val_loss: 0.0460 - val_accuracy: 0.9882
# Epoch 7/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0282 - accuracy: 0.9917 - val_loss: 0.0581 - val_accuracy: 0.9852
# Epoch 8/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0214 - accuracy: 0.9935 - val_loss: 0.0418 - val_accuracy: 0.9906
# Epoch 9/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0216 - accuracy: 0.9934 - val_loss: 0.0490 - val_accuracy: 0.9894
# Epoch 10/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0180 - accuracy: 0.9943 - val_loss: 0.0526 - val_accuracy: 0.9906
# Epoch 11/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0597 - val_accuracy: 0.9896
# Epoch 12/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.0720 - val_accuracy: 0.9886
# Epoch 13/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.0494 - val_accuracy: 0.9914
# Epoch 14/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0458 - val_accuracy: 0.9910
# Epoch 15/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.0607 - val_accuracy: 0.9880
# Epoch 16/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0554 - val_accuracy: 0.9904
# Epoch 17/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0638 - val_accuracy: 0.9898
# Epoch 18/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.0527 - val_accuracy: 0.9906
# Epoch 19/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.0603 - val_accuracy: 0.9906
# Epoch 20/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.0646 - val_accuracy: 0.9920
# Epoch 21/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.0707 - val_accuracy: 0.9902
# Epoch 22/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0102 - accuracy: 0.9972 - val_loss: 0.0857 - val_accuracy: 0.9904
# Epoch 23/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.0618 - val_accuracy: 0.9926
# Epoch 24/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 0.0581 - val_accuracy: 0.9918
# Epoch 25/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0800 - val_accuracy: 0.9906
# Epoch 26/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 0.0696 - val_accuracy: 0.9930
# Epoch 27/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0102 - accuracy: 0.9975 - val_loss: 0.0723 - val_accuracy: 0.9914
# Epoch 28/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.0778 - val_accuracy: 0.9924
# Epoch 29/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0096 - accuracy: 0.9976 - val_loss: 0.0734 - val_accuracy: 0.9924
# Epoch 30/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0105 - accuracy: 0.9972 - val_loss: 0.0761 - val_accuracy: 0.9914

# %%
# show the structure of your model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        3200
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 881,290
# Trainable params: 881,290
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Assume you have stored the training history in the variable "history"
# Show the learning curves
pd.DataFrame(history.history).plot(figsize=(12, 8))
plt.gca().set_ylim(0, 1)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Save the model
#
# Save and upload your trained model to the seafile link we provided to you. You can upload it multiple times. We will consider only the newest uploaded model.

# %%
model.save('FDS22-M024-MNIST.h5') # change the file name according to your repository name

# %% [markdown]
# ## Load the model and evaluate it on the test data

# %%
model = keras.models.load_model("FDS22-M024-MNIST.h5")
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0413 - accuracy: 0.9934
# [0.041311826556921005, 0.993399977684021]

# %% [markdown]
# ## Short report
#
# Please write a few sentences explaining how you build and train the model. Please include the decisions you made, such as why you use x number layers and the difficulties you met.
